# %% [markdown]
# ### Section 3:
#
# The digital economy is like a "double-edged sword" that can improve efficiency, optimize services, and expand markets. It also brings risks such as data privacy, job loss, monopolies, and unfair competition. To this end, we found the Canadian policy paper on the digital economy and the corresponding report and read the text efficiently through the method of text analysis.
#
# **RQ3：Text analysis of reports related to Canada’s digital economy.**
#
# For text analysis, we mainly employ three tools: word cloud, LDA, and NetworkX. The word cloud is generated based on the high-frequency words of the corresponding topic, visualizing the most frequent words in a visually appealing way. Latent Dirichlet Allocation (LDA) algorithm creates a bar chart to visualize the top words and their frequency for each topic. x-axis indicates the most frequent words and y-axis indicates the frequency of occurrence. The network graph visually represents the connections between words in the text. Nodes represent individual words and edges represent sequential relationships between words. By examining the network graph, patterns, clusters, or centroids can be identified that provide insight into the structure of content or relationships between words in a document.

# %%
import pdfplumber
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import networkx as nx
from PyPDF2 import PdfReader

# %%
pdf_file = 'ITS-Policy-Report-01-2023-Rethinking-Competition-d2-2.pdf'
with pdfplumber.open(pdf_file) as pdf:
    text = ""
    for page in pdf.pages:
        text += page.extract_text()
    words_to_remove = ['see', '#','&','-','an', 'use','-).', '’', 'it', 'To', 'also', 'infer', 'the', 'and', 'or', 'data', 'no', 'is', 'for',
                    'of', 'to', 'these', 'end', 'This', '•', '�', '—', 'THE', 'in', 'on', 'by', 'that', 'as', 'are',
                    'this', 'have', 'their', 'The', 'all','we','our','was',',', '.', '-', '(', ')', '/', ':']  
    symbols_to_remove = [',', '.', '-', '(', ')', '/', ':','#','&']  
    pattern_words = r'\b(?:{})\b'.format('|'.join(map(re.escape, words_to_remove)))
    text = re.sub(pattern_words, '', text, flags=re.IGNORECASE)
    text = re.sub(r'\d+', '', text)
    for symbol in symbols_to_remove:
        text = text.replace(symbol, '')
     
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Rethinking Canada’s Competition Policy in the Digital Economy')
    plt.show()
pdf_reader = PdfReader(pdf_file)
start_page = 1
end_page = 1
text = ""
for page_number in range(start_page - 1, end_page):
    page = pdf_reader.pages[page_number]
    text += page.extract_text()
words_to_remove = ['see', '#','&','-','an', 'use','-).', '’', 'it', 'To', 'also', 'infer', 'the', 'and', 'or', 'data', 'no', 'is', 'for',
                    'of', 'to', 'these', 'end', 'This', '•', '�', '—', 'THE', 'in', 'on', 'by', 'that', 'as', 'are',
                    'this', 'have', 'their', 'The', 'all','we','our','was',',', '.', '-', '(', ')', '/', ':']  
symbols_to_remove = [',', '.', '-', '(', ')', '/', ':','#','&']
pattern_words = r'\b(?:{})\b'.format('|'.join(map(re.escape, words_to_remove)))
text = re.sub(pattern_words, '', text, flags=re.IGNORECASE)
text = re.sub(r'\d+', '', text)
for symbol in symbols_to_remove:
    text = text.replace(symbol, '')
words = text.split()
G = nx.Graph()
for word in set(words):
    G.add_node(word)
for i in range(len(words) - 1):
    G.add_edge(words[i], words[i + 1])
pos = nx.spring_layout(G)
fig=plt.figure(figsize=(15, 12))
nx.draw(G, pos, with_labels=True, node_color='lightpink', node_size=1000, font_size=8, edge_color='gray',ax=fig.gca())
plt.title('NetworkX Diagram of Rethinking Canada’s Competition Policy in the Digital Economy')
plt.show()

# %% [markdown]
# NetworkX graph is useful for text analysis because it helps reveal patterns in the way that words are used together. It can be used to identify key terms that are frequently mentioned together, which helps us understand the structure of the text.
#
# By using tools such as word clouds and LDA, we can effortlessly identify the most frequently used words in a given text: digital, competition, policy, market, and personal... This document presents an international policy analysis that examines market reforms driven by the rise of data-driven economies. Through this analysis, Canadian policymakers can develop an innovative competition policy framework that fosters growth and progress. The research also highlights potential concerns around privacy and data protection for Canadian web users, stemming from the impact of the digital economy.

# %%
pdf_file = 'C:/Users/Wild/Desktop/商务智能/data/Policy literature/Blakes_Digital_Economy_Report_Dec_2019_Digital.pdf'
pdf_reader = PdfReader(pdf_file)
start_page = 1
end_page = 2
text = ""
for page_number in range(start_page - 1, end_page):
    page = pdf_reader.pages[page_number]
    text += page.extract_text()
words_to_remove = ['key','Key','in','the', 'and', 'or', 'data','no','is','for','of','to','these','end','This']  
pattern = r'\b(?:{})\b'.format('|'.join(words_to_remove))
text = re.sub(pattern, '', text, flags=re.IGNORECASE)
text = re.sub(r'\d+', '', text)
print(text)
words = text.split()
G = nx.Graph()
for word in set(words):
    G.add_node(word)
for i in range(len(words) - 1):
    G.add_edge(words[i], words[i + 1])
pos = nx.spring_layout(G)
fig=plt.figure(figsize=(15, 12))
nx.draw(G, pos, with_labels=True, node_color='c', node_size=1000, font_size=8, edge_color='gray',ax=fig.gca())
plt.title('NetworkX Diagram of Competition Law and the Digital Economy in Canada')
plt.show()
# Out:
# Competition Law
#  Digital Economy
#  Canada
#  Issues  Practical Implications
#  digital economy, big   emerging technologies have vaulted
#   top   priority list  antitrust enforcement agencies around
#  world,  Canada   exception.  guidebook outlines  most
# important emerging trends  provides  practical tips  Canadian
# companies  navigate  issues going forward.

# %% [markdown]
# # Conclusion:
# By utilizing matplotlib library’s common methods and text analysis tools , we have concluded that Canada boasts a highly developed digital economy, with e-commerce sales showing a steady year-on-year increase from 2017 to 2022. This has resulted in an influx of enterprises and merchants actively embracing the digital economy trend, with a promising outlook for booming e-commerce.
#
# Through the implementation of machine learning, we predicted that individuals who are younger and possess higher levels of education are more susceptible to network security attacks. Additionally, a time series forecast has been utilized to predict the percentage of companies within each industry that will experience cyber attacks in 2023.
#
# Finally, based on the findings from our data analysis, we conducted an analysis of the policy documents related to Canada's digital economy, performing both topic and text analysis to identify relevant keywords, which allowed us to gain deeper insights into the key themes and focus areas outlined in the policy report.
#
# Our recommendations for the development of Canada's digital economy are as follows:  invest in digital infrastructure like high-speed internet; promote digital skills training to equip Canadians with the necessary know-how to thrive in this digital age; protect digital privacy and enhance digital security.
#
# By following these recommendations, Canada can capitalize on the opportunities presented by the digital age to drive economic growth. Canadian businesses have the potential to increase efficiency and productivity, create jobs, improve public services, and foster innovation. It is advantageous to build a strong and thriving digital economy in Canada.

# %% [markdown]
# # Reference:
#
# Birch, Kean, and Damola Adediji. “Rethinking Canada’s Competition Policy in the Digital Economy.” Faculty of Environmental and Urban Change, 25 Mar. 2023, euc.yorku.ca/research-spotlight/rethinking-canadas-competition-policy-in-the-digital-economy/#:~:text=The%20Rethinking%20Canada%E2%80%99s%20Competition%20Policy%20in%20the%20Digital,various%20countries%2C%20jurisdictions%20and%20institutions%20around%20the%20globe.
#
# Competition Law and the Digital Economy in Canada - Key Issues and Practical Implications. Blakes, www.blakes.com/insights/bulletins/2019/competition-law-and-the-digital-economy-in-canada. Accessed 12 June 2023.
# Canadian Perspectives Survey Series 5: Technology Use and Cyber Security during the Pandemic. Government of Canada, 6 Feb. 2021, DOI: https://doi.org/10.25318/45250010-eng
#
# Canadian internet use survey, 2020. (2021, June 22). Statistics Canada: Canada's national statistical agency / Statistique Canada : Organisme statistique national du Canada. https://www150.statcan.gc.ca/n1/daily-quotidien/210622/dq210622b-eng.htm
#
# Digital economy survey. (2018, August 28). Statistics Canada - Access forbidden! (Error 403) | Statistique Canada - Accès interdit ! (Erreur 403). https://www23.statcan.gc.ca/imdb/p2SV.pl?Function=getSurvey&SDDS=5265
#
# Digital supply and use tables, 2017 to 2019. (2021, April 20). Statistics Canada: Canada's national statistical agency / Statistique Canada : Organisme statistique national du Canada. https://www150.statcan.gc.ca/n1/daily-quotidien/210420/dq210420a-eng.htm
#
# E-Commerce and the consumer price index: Measuring inflation in a digital economy. (2019, September 27). Statistics Canada: Canada's national statistical agency / Statistique Canada : Organisme statistique national du Canada. https://www150.statcan.gc.ca/n1/pub/62f0014m/62f0014m2019008-eng.htm
#
# Internet use by selected characteristics, 2020. (2021, June 22). Statistics Canada: Canada's national statistical agency / Statistique Canada : Organisme statistique national du Canada. https://www150.statcan.gc.ca/n1/daily-quotidien/210622/t001b-eng.htm
#
# Measuring digital intensity in the Canadian economy. (2021, February 24). Statistics Canada: Canada's national statistical agency / Statistique Canada : Organisme statistique national du Canada. https://www150.statcan.gc.ca/n1/pub/36-28-0001/2021002/article/00003-eng.htm
#
# Government of Canada, Statistics Canada (2022a) Reporting of cyber security incidents to a police service by industry and size of Enterprise, Reporting of cyber security incidents to a police service by industry and size of enterprise. Available at: https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=2210007801
#
# Report to the Clerk of the Privy Council: A Data Strategy Roadmap for the Federal Public Service. Government of Canada, 6 Dec. 2018, www.canada.ca/en/privy-council/corporate/clerk/publications/data-strategy.html.
